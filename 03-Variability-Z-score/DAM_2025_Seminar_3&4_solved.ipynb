# %% [markdown]
# # Seminars 3&4

# %% [markdown]
# ## GitHub

# %% [markdown]
# Your final project should ba availible on GitHub
#
# Instructions:
#
# *   [How to register](https://docs.github.com/en/get-started/start-your-journey/creating-an-account-on-github)
# *   [How to create a repository](https://docs.github.com/en/repositories/creating-and-managing-repositories/quickstart-for-repositories)
# *   [How to add collaborators](https://docs.github.com/ru/account-and-profile/how-tos/setting-up-and-managing-your-personal-account-on-github/managing-access-to-your-personal-repositories/inviting-collaborators-to-a-personal-repository)

# %% [markdown]
# ## Pandas

# %% [markdown]
# On the previous seminar we worked with population of different countries, we had 2 arrays: data and the names of the countries. It is not convenient, better have one *table*, like in Excel.

# %% [markdown]
# Let's try it in Numpy:

# %%
import numpy as np

dummy_data = np.array([['A', 12, 13],
                      ['B', 4, 5],
                      ['C', 8, 10]])
dummy_data
# Out:
# array([['A', '12', '13'],
#        ['B', '4', '5'],
#        ['C', '8', '10']], dtype='<U21')

# %% [markdown]
# All of the elements are strings! Because in Numpy array all elements must have same type.
#
# We cannot compute anything:

# %%
dummy_data[0][1], dummy_data[0][2]
# Out:
# (np.str_('12'), np.str_('13'))

# %%
#error! - cannot multiply strings
dummy_data[0][1] * dummy_data[0][2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2565859568.py in <cell line: 0>()
#       1 #error! - cannot multiply strings
# ----> 2 dummy_data[0][1] * dummy_data[0][2]
#
# TypeError: can't multiply sequence by non-int of type 'numpy.str_'

# %% [markdown]
# Pandas - library for working with tables (datasets)
#
# Why use pandas:
#
#
#
# *   Convenient table representation
# *   A lot of functions for tables (as in Excel)
# *   Visualization (embedded + some libraries are design for pandas dataFrames)
#
#
#
#
# Documentation - https://pandas.pydata.org/docs/

# %%
import pandas as pd

# %% [markdown]
# Table in pandas is called `DataFrame`

# %%
df = pd.DataFrame([['A', 12, 13],
                      ['B', 4, 5],
                      ['C', 8, 10]])
df
# Out:
#    0   1   2
# 0  A  12  13
# 1  B   4   5
# 2  C   8  10

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The columns are `Series` - 1D array, with index labels.

# %%
df[0]
# Out:
# 0    A
# 1    B
# 2    C
# Name: 0, dtype: object

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# We can take the values of the table as a numpy array

# %%
df.values
# Out:
# array([['A', 12, 13],
#        ['B', 4, 5],
#        ['C', 8, 10]], dtype=object)

# %% [markdown]
# Some real data  - Titanic datasets

# %%
# !wget https://raw.githubusercontent.com/Majid-Sohrabi/MLDM-2025/refs/heads/main/01-intro/train.csv
df = pd.read_csv("train.csv")
df.head()
# Out:
# --2025-10-10 15:41:37--  https://raw.githubusercontent.com/Majid-Sohrabi/MLDM-2025/refs/heads/main/01-intro/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  58.89K  --.-KB/s    in 0.02s
#
# 2025-10-10 15:41:37 (3.45 MB/s) - ‘train.csv’ saved [60302/60302]
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# ...

# %% [markdown]
# Columns:
#
# *  **PassengerId** - The ID of the passenger
# *   **Survived** - 	Survival of the passenger;	0 = No, 1 = Yes
# * **Pclass**	- Ticket class;	1 = 1st, 2 = 2nd, 3 = 3rd
# * **Sex**	- Sex of the passenger
# *   **Age** -	Age in years
# *   **SibSp**	- Number of siblings / spouses aboard the Titanic
# * **Parch**	- Number of parents / children aboard the Titanic
# * **Ticket**	- Ticket number
# * **Fare**	- Passenger fare
# * **Cabin**	- Cabin number
# * **Embarked**	- Port of Embarkation;	C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# First rows:

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# Last rows:

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# Random rows:

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 466          467         0       2                      Campbell, Mr. William
# 887          888         1       1               Graham, Miss. Margaret Edith
# 274          275         1       3                 Healy, Miss. Hanora "Nora"
# 577          578         1       1  Silvey, Mrs. William Baird (Alice Munger)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 326    male  61.0      0      0  345364   6.2375   NaN        S
# 466    male   NaN      0      0  239853   0.0000   NaN        S
# 887  female  19.0      0      0  112053  30.0000   B42        S
# 274  female   NaN      0      0  370375   7.7500   NaN        Q
# 577  female  39.0      1      0   13507  55.9000   E44        S

# %% [markdown]
# We can start by checking the basic information about the DataFrame

# %% [markdown]
# ### Variables' types

# %% [markdown]
# There are numerical and categorical (nominal, ordinal) variables.
#
# We need to know the type of every variable to work with it.
#
# Let's check the types of columns in `df` and the description of the columns and try to understand the type of every feature of passengers.

# %%
#Types of columns
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
#number of rows
len(df)
# Out:
# 891

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Indexing

# %% [markdown]
# We can choose columns

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# The columns are `Series` - 1D array, with index labels.

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Why index labels matter? Why are they bold in DataFrame and why are they preserved in Series?
#
# ...
#
# Because they are ids of rows/elements and they are not always numbers 0, 1, ...
#
#
# Let's firstly look on how to choose rows: methods `loc` and `iloc`

# %%
#choose row with index = 1
df.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
#choose row, which relative position is 1
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %% [markdown]
# No difference? Let's check the following example:

# %%
np.random.seed(0)
sample = df.sample(3)

sample
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex  Age  SibSp  \
# 495          496         0       3  Yousseff, Mr. Gerious  male  NaN      0
# 648          649         0       3     Willey, Mr. Edward  male  NaN      0
# 278          279         0       3     Rice, Master. Eric  male  7.0      4
#
#      Parch         Ticket     Fare Cabin Embarked
# 495      0           2627  14.4583   NaN        C
# 648      0  S.O./P.P. 751   7.5500   NaN        S
# 278      1         382652  29.1250   NaN        Q

# %% [markdown]
# The relative position 1 is occupied by Edward (648 index)

# %%
sample.iloc[1]
# Out:
# PassengerId                   649
# Survived                        0
# Pclass                          3
# Name           Willey, Mr. Edward
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Ticket              S.O./P.P. 751
# Fare                         7.55
# Cabin                         NaN
# Embarked                        S
# Name: 648, dtype: object

# %% [markdown]
# But there is no index 1, so `loc` will give an error:

# %%
#errors
sample.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-641626339.py in <cell line: 0>()
#       1 #errors
# ----> 2 sample.loc[1]
#
# ...

# %%
sample.loc[648]
# Out:
# PassengerId                   649
# Survived                        0
# Pclass                          3
# Name           Willey, Mr. Edward
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Ticket              S.O./P.P. 751
# Fare                         7.55
# Cabin                         NaN
# Embarked                        S
# Name: 648, dtype: object

# %% [markdown]
# When we take the column of our sample, the indices will be perserved.

# %%
sample['Age']
# Out:
# 495    NaN
# 648    NaN
# 278    7.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Add/delete columns

# %% [markdown]
# We often need to create new features based on old ones or delete the extr ones.

# %%
df['Random'] = np.random.rand(len(df))
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 339          340         0       1          Blackwell, Mr. Stephen Weart
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked    Random
# 867  male  31.0      0      0  PC 17590  50.4958   A24        S  0.404774
# 339  male  45.0      0      0    113784  35.5000     T        S  0.922299

# %% [markdown]
# There was no `'Random'` column, we created it (like in python `dict`, just entered a new key)
#
# We also can use old columns to create new

# %%
df['Fare'] * 2
# Out:
# 0       14.5000
# 1      142.5666
# 2       15.8500
# 3      106.2000
# 4       16.1000
#          ...
# 886     26.0000
# 887     60.0000
# 888     46.9000
# 889     60.0000
# 890     15.5000
# Name: Fare, Length: 891, dtype: float64

# %%
df['Double_Fare'] =  df['Fare'] * 2
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 13            14         0       3  Andersson, Mr. Anders Johan  male  39.0
# 179          180         0       3          Leonard, Mr. Lionel  male  36.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked    Random  Double_Fare
# 13       1      5  347082  31.275   NaN        S  0.457059        62.55
# 179      0      0    LINE   0.000   NaN        S  0.208253         0.00

# %%
df['Fare_Random'] =  df['Fare'] + df['Random']
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 125          126         1       3            Nicola-Yarred, Master. Elias
# 348          349         1       3  Coutts, Master. William Loch "William"
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked    Random  \
# 125  male  12.0      1      0        2651  11.2417   NaN        C  0.675689
# 348  male   3.0      1      1  C.A. 37671  15.9000   NaN        S  0.506863
#
#      Double_Fare  Fare_Random
# 125      22.4834    11.917389
# 348      31.8000    16.406863

# %%
df['Big_Fare'] =  (df['Fare'] > 100).astype('int64')
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 746          747         0       3  Abbott, Mr. Rossmore Edward    male  16.0
# 580          581         1       2  Christy, Miss. Julie Rachel  female  25.0
#
#      SibSp  Parch     Ticket   Fare Cabin Embarked    Random  Double_Fare  \
# 746      1      1  C.A. 2673  20.25   NaN        S  0.556133         40.5
# 580      1      1     237789  30.00   NaN        S  0.244570         60.0
#
#      Fare_Random  Big_Fare
# 746    20.806133         0
# 580    30.244570         0

# %% [markdown]
# **Task** Create column `FamilySize` that will contain the size of the passenger's family. F.e. if passenger has 4 siblings and 2 parent on the Titanic, their family size is 7.

# %%
#your code here
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df.sample(13)
# Out:
#      PassengerId  Survived  Pclass  \
# 573          574         1       3
# 750          751         1       2
# 370          371         1       1
# 245          246         0       1
# 352          353         0       3
# 220          221         1       3
# 410          411         0       3
# 836          837         0       3
# 191          192         0       2
# 199          200         0       2
# 700          701         1       1
# 595          596         0       3
# 109          110         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 573                                  Kelly, Miss. Mary  female   NaN      0
# 750                                  Wells, Miss. Joan  female   4.0      1
# 370                        Harder, Mr. George Achilles    male  25.0      1
# 245                        Minahan, Dr. William Edward    male  44.0      2
# 352                                 Elias, Mr. Tannous    male  15.0      1
# ...

# %% [markdown]
# **Task** Create  column `isAlone` that contains `True/False` - information that passenger is travelling alone.

# %%
#your code here
df['isAlone'] = df['FamilySize'] == 1
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 462          463         0       1              Gee, Mr. Arthur H    male
# 681          682         1       1             Hassab, Mr. Hammad    male
# 140          141         0       3  Boulos, Mrs. Joseph (Sultana)  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked    Random  \
# 462  47.0      0      0    111320  38.5000   E63        S  0.066074
# 681  27.0      0      0  PC 17572  76.7292   D49        C  0.960813
# 140   NaN      0      2      2678  15.2458   NaN        C  0.156383
#
#      Double_Fare  Fare_Random  Big_Fare  FamilySize  isAlone
# 462      77.0000    38.566074         0           1     True
# 681     153.4584    77.690013         0           1     True
# 140      30.4916    15.402183         0           3    False

# %% [markdown]
# All the new columns were created using math or bool operations. What if we have some more complex function?
#
# For example, we want to have column 'name_length'

# %%
len(df['Name'])
# Out:
# 891

# %% [markdown]
# The code does not compute `len` for every name, but to the Series itself.
#
# To apply function we can use `apply` (or `for`-loop, but they are slow)

# %%
df['Name'].apply(len)
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %% [markdown]
# **Task:** Every full name contains a title (Mr, Mrs, ...), extract it and put into new column.

# %%
df.sample()
# Out:
#     PassengerId  Survived  Pclass                  Name   Sex  Age  SibSp  \
# 16           17         0       3  Rice, Master. Eugene  male  2.0      4
#
#     Parch  Ticket    Fare Cabin Embarked    Random  Double_Fare  Fare_Random  \
# 16      1  382652  29.125   NaN        Q  0.857125        58.25    29.982125
#
#     Big_Fare  FamilySize  isAlone
# 16         0           6    False

# %%
s = 'Rice, Master. Eugene'
s.split(', ')[1].split('.')[0]
# Out:
# 'Master'

# %%
def extract_title(s):
  #Hassab, Mr. Hammad
  #Jardin, Mr. Jose Neto
  #your code here
  return s.split(', ')[1].split('.')[0]



df['Title'] = df['Name'].apply(extract_title)

df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 540          541         1       1           Crosby, Miss. Harriet R  female
# 609          610         1       1         Shutes, Miss. Elizabeth W  female
# 846          847         0       3          Sage, Mr. Douglas Bullen    male
# 219          220         0       2                Harris, Mr. Walter    male
# 197          198         0       3  Olsen, Mr. Karl Siegwart Andreas    male
#
#       Age  SibSp  Parch     Ticket      Fare Cabin Embarked    Random  \
# 540  36.0      0      2  WE/P 5735   71.0000   B22        S  0.367475
# 609  40.0      0      0   PC 17582  153.4625  C125        S  0.598316
# 846   NaN      8      2   CA. 2343   69.5500   NaN        S  0.657862
# 219  30.0      0      0  W/C 14208   10.5000   NaN        S  0.600213
# 197  42.0      0      1       4579    8.4042   NaN        S  0.107211
#
#      Double_Fare  Fare_Random  Big_Fare  FamilySize  isAlone Title
# ...

# %%
df.sample(5)[['Name', 'Title']]
# Out:
#                                                Name Title
# 705  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    Mr
# 593                              Bourke, Miss. Mary  Miss
# 96                        Goldschmidt, Mr. George B    Mr
# 701                Silverthorne, Mr. Spencer Victor    Mr
# 836                                Pasic, Mr. Jakob    Mr

# %% [markdown]
# To delete column/rows we can use `drop` function

# %%
df.drop(columns=['Big_Fare', 'Fare_Random', 'Double_Fare', 'Random'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 785          786         0       3  Harmer, Mr. Abraham (David Lishin)
# 491          492         0       3                 Windelov, Mr. Einar
# 485          486         0       3              Lefebre, Miss. Jeannie
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 785    male  25.0      0      0            374887   7.2500   NaN        S
# 491    male  21.0      0      0  SOTON/OQ 3101317   7.2500   NaN        S
# 485  female   NaN      3      1              4133  25.4667   NaN        S
#
#        Random  Double_Fare  Fare_Random  Big_Fare  FamilySize  isAlone Title
# 785  0.396610      14.5000     7.646610         0           1     True    Mr
# 491  0.947822      14.5000     8.197822         0           1     True    Mr
# 485  0.002065      50.9334    25.468765         0           5    False  Miss

# %% [markdown]
# But the columns are still there ...
#
# Important: many functions which change the dataframe are not inplace, they return a **copy**

# %%
new_df = df.drop(columns=['Big_Fare', 'Fare_Random', 'Double_Fare', 'Random'])
#change something in new_df
new_df['Age'] = 0
new_df['Parch'] = -12321
new_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male    0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    0      1
#
#    Parch     Ticket     Fare Cabin Embarked  FamilySize  isAlone Title
# 0 -12321  A/5 21171   7.2500   NaN        S           2    False    Mr
# 1 -12321   PC 17599  71.2833   C85        C           2    False   Mrs

# %%
#initial is untouched
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked    Random  Double_Fare  \
# 0      0  A/5 21171   7.2500   NaN        S  0.147809      14.5000
# 1      0   PC 17599  71.2833   C85        C  0.684934     142.5666
#
#    Fare_Random  Big_Fare  FamilySize  isAlone Title
# 0     7.397809         0           2    False    Mr
# 1    71.968234         0           2    False   Mrs

# %% [markdown]
# We need to save the changes (use `inplace=True` or `df = df.drop(...)`)

# %%
#df = df.drop(columns=['Big_Fare', 'Fare_Random', 'Double_Fare', 'Random'])
df.drop(columns=['Big_Fare', 'Fare_Random', 'Double_Fare', 'Random'], inplace=True)
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 321          322         0       3              Danoff, Mr. Yoto  male  27.0
# 545          546         0       1  Nicholson, Mr. Arthur Ernest  male  64.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  FamilySize  isAlone Title
# 321      0      0  349219   7.8958   NaN        S           1     True    Mr
# 545      0      0     693  26.0000   NaN        S           1     True    Mr

# %% [markdown]
# ###Filtering

# %% [markdown]
# As in numpy we can filter based on some condidions (for columns)

# %% [markdown]
# Choosing all women on Titanic

# %%
df['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df[df['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Choosing adults:

# %%
df[df['Age'] >= 18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Ages of adults:

# %%
df[df['Age'] > 18]['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 575, dtype: float64

# %% [markdown]
# If we have several conditions we can use & (and), | (or)

# %% [markdown]
# People who are younger than 18 (kids) or older than 60 (old people)

# %%
df[(df["Age"]<18) |  (df["Age"]>60)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 851          852         0       3                   Svensson, Mr. Johan
# 852          853         0       3               Boulos, Miss. Nourelain
# 853          854         1       1             Lines, Miss. Mary Conover
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  FamilySize  \
# ...

# %% [markdown]
# Women who are adults:

# %%
df[(df['Sex'] == 'female') & (df['Age'] >= 18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 879          880         1       1
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# We can combine & and | and use `()`
#
# Women who were in 1 or 2 class:

# %%
df[((df['Pclass'] == 1) | (df['Pclass'] == 2)) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 11            12         1       1
# 15            16         1       2
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Something more complex - women from 18 to 25 who embarked in Cherbourg(С), or Southampton (S)

# %%
df[((df['Embarked'] =='C') | (df['Embarked'] =='S')) & (df['Sex'] == 'female') &
     (df['Age'] >= 18) & (df['Age'] <= 25)]
# Out:
#      PassengerId  Survived  Pclass  \
# 38            39         0       3
# 49            50         0       3
# 56            57         1       2
# 88            89         1       1
# 106          107         1       3
# ..           ...       ...     ...
# 855          856         1       3
# 858          859         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 38              Vander Planke, Miss. Augusta Maria  female  18.0      2
# 49   Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 56                               Rugg, Miss. Emily  female  21.0      0
# 88                      Fortune, Miss. Mabel Helen  female  23.0      3
# 106               Salkjelsvik, Miss. Anna Kristine  female  21.0      0
# ..                                             ...     ...   ...    ...
# ...

# %% [markdown]
# After we filter our data we may want to count the number of rows (not depict them), we may use `.shape[0]`

# %% [markdown]
# F.e. number of adult women on the Titanic

# %%
df[(df['Sex'] == 'female') & (df['Age'] >= 18)].shape[0]
# Out:
# 206

# %% [markdown]
# **Task:** Compute number of people who paid more than 100 for the ticket

# %%
#your code here
len(df[df['Fare'] > 100])
# Out:
# 53

# %% [markdown]
# **Task:** Depict women, who travelled with more than 4 siblings

# %%
#your code here
df[(df['SibSp'] > 4) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 71            72         0       3         Goodwin, Miss. Lillian Amy  female
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked  FamilySize  isAlone  \
# 71   16.0      5      2   CA 2144  46.90   NaN        S           8    False
# 180   NaN      8      2  CA. 2343  69.55   NaN        S          11    False
# 792   NaN      8      2  CA. 2343  69.55   NaN        S          11    False
# 863   NaN      8      2  CA. 2343  69.55   NaN        S          11    False
#
#     Title
# 71   Miss
# 180  Miss
# 792  Miss
# 863  Miss

# %% [markdown]
# **Task:** Depict Names and Ages of  passengers who survived the Titanic and were in cabin G6

# %%
#your code here
df[(df['Cabin'] == 'G6') & (df['Survived'] == 1)][['Name', 'Age']]
# Out:
#                                                   Name   Age
# 10                     Sandstrom, Miss. Marguerite Rut   4.0
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  24.0

# %% [markdown]
# ### Sorting

# %% [markdown]
# Sort rows by ascending age:

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# If we want to sort in descending order:

# %%
df.sort_values('Age', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# If we want to sort based on several columns (firstly by age, if passengers have the same age - by fare)

# %%
df.sort_values(['Age', 'Fare'], ascending=[False, True])
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                                Svensson, Mr. Johan    male  74.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Unique values, aggregating

# %% [markdown]
# Very often we need to check which uniqe values do we have in our data (which cities are respondents from? What steps of educations?)

# %% [markdown]
# In the data description it was said that there are 3 classes on Titanic, let's check it:

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# Number of unique values:

# %%
df.Pclass.nunique()
# Out:
# 3

# %% [markdown]
# If we want to know how many passengers were in each class:

# %%
df.value_counts('Pclass')
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.value_counts('Sex') #Counting number of men/women
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# **Task** What conclusions can we make bassed on the data above?

# %% [markdown]
# We also may want to check number of women/men in each class. We cannot do it using `value_counts` because it works with one column.
#
# Let's use function `groupby` - it divides the data based on several columns:

# %%
class_sex_groups = df.groupby(['Pclass', 'Sex'])
class_sex_groups #Some special object

# %% [markdown]
# After we grouped our data, we can aggregate - compute sum, mean, number of observations of the group.
#
# If we want to compute number of people in each group:

# %%
class_sex_groups['PassengerId'].count()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: PassengerId, dtype: int64

# %% [markdown]
# **Task** What conclusions can we make bassed on the data above?

# %% [markdown]
# We may want to compute the minimum fare for each group:

# %%
class_sex_groups['Fare'].min()
# Out:
# Pclass  Sex
# 1       female    25.9292
#         male       0.0000
# 2       female    10.5000
#         male       0.0000
# 3       female     6.7500
#         male       0.0000
# Name: Fare, dtype: float64

# %% [markdown]
# # New data, new tasks

# %%
data = pd.read_csv('https://raw.githubusercontent.com/cstorm125/information_value/master/data/120-years-of-olympic-history-athletes-and-results/athlete_events.csv')
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data['Medal'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
data.shape
# Out:
# (271116, 15)

# %% [markdown]
# **Task** Investigate features, name their types:

# %% [markdown]
# Columns :
# * **ID** - Unique number for each athlete
# * **Name** - Athlete's name
# * **Sex** - M or F
# * **Age** - Integer
# * **Height** - In centimeters
# * **Weight** - In kilograms
# * **Team** - Team name
# * **NOC** - National Olympic Committee 3-letter code
# * **Games** - Year and season
# * **Year** - Integer
# * **Season** - Summer or Winter
# * **City** - Host city
# * **Sport**  - Sport
# * **Event** - Event
# * **Medal** - Gold, Silver, Bronze, or NA

# %% [markdown]
# **Task** How many athletes are heavier than 80 kgs?

# %%
#your code here
data[data['Weight'] > 80].shape[0]
# Out:
# 44854

# %% [markdown]
# **Task** How many female athletes are shorter than 1.85 m?

# %%
#your code here
data[(data['Height'] < 185) & (data['Sex'] == 'F')].shape[0]
# Out:
# 65357

# %% [markdown]
# **Task** In how many Olympic games did Edgar Lindenau Aabye participated in?

# %%
#your code here
data[data['Name'] == 'Edgar Lindenau Aabye']['Games'].nunique()
# Out:
# 1

# %% [markdown]
# **Task** How many gold medals did China win in diving during summer Olympic Games?

# %%
#your code here
data[(data['Medal'] == 'Gold') & (data['Team'] == 'China') & (data['Sport'] == 'Diving') & (data['Season'] == 'Summer')].shape[0]
# Out:
# 56

# %% [markdown]
# **Task** In which cities were box competitions held before year 2000 (including 2000)?

# %%
#your code here
data[(data['Year'] <= 2000) & (data['Sport'] == 'Boxing')]['City'].unique()
# Out:
# array(['London', 'Seoul', 'Munich', 'Mexico City', 'Paris', 'Roma',
#        'Helsinki', 'Sydney', 'Montreal', 'Atlanta', 'Moskva',
#        'Los Angeles', 'Barcelona', 'Tokyo', 'Antwerpen', 'Melbourne',
#        'Berlin', 'Amsterdam', 'St. Louis'], dtype=object)

# %% [markdown]
# **Task** How many (total) gold and silver medals did Kazakhstan won in competition `Weightlifting Women's Middleweight`?

# %%
#your code here
data[(data['Team'] == 'Kazakhstan') & (data['Event'] == "Weightlifting Women's Middleweight")&
     ((data['Medal'] == 'Gold') | (data['Medal'] == 'Silver'))].shape[0]
# Out:
# 2

# %% [markdown]
# **Task** Compute the total number of times an athelete participated in Olympic games, depict the top-5 people who participated in most games.

# %%
#your code here
data.groupby('Name')['Games'].nunique().sort_values(ascending=False)[:5]
# Out:
# Name
# Ian Millar                         10
# Hubert Raudaschl                    9
# Afanasijs Kuzmins                   9
# Raimondo D'Inzeo                    8
# Nino Salukvadze (-Machavariani)     8
# Name: Games, dtype: int64

# %% [markdown]
# **Task** Create column with BMI of an athlete
#
# $BMI = \frac{m}{h^2}$
#
# where $m$ - weight in kg, $h$ - height in meters.

# %%
#your code here
data['BMI'] = data['Weight'] / ((data['Height'] / 100) ** 2)

data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal        BMI
# 0       Basketball Men's Basketball   NaN  24.691358
# ...

# %% [markdown]
# **Task** Standerd cetegories for BMI:
#
# *   $< 18.5$ - Underweight
# *   $[18.5; 25.0)$  - Normal
# *   $[25.0; 30.0)$ - Overweight
# *   $>= 30.0$ - Obese
#
#
# Compute the BMI category for every athelete, save to `Category_BMI` column (if BMI was NaN - category should also be NaN). Compute number of athletes in every category.

# %%
#your code here
def bmi_categ(bmi):
  if bmi < 18.5:
    return 'Underweight'
  if 18.5 <= bmi < 25:
    return 'Normal'
  if 25 <= bmi < 30:
    return 'Overweight'
  if bmi >= 30:
    return  'Obese'

  return np.nan

data['Category_BMI'] = data['BMI'].apply(bmi_categ)
data.sample(4)
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 237414  119071           Kristina Minna Telde   F  37.0   166.0    54.0
# 135017   67937                  Lee Hui-Cheng   F  16.0   166.0    68.0
# 248276  124300  Marinus "Rinus" van den Berge   M  24.0   171.0    65.0
# 149894   75172           Margit Mark-Nemeshzi   F  24.0   163.0    54.0
#
#                   Team  NOC        Games  Year  Season         City  \
# 237414          Sweden  SWE  2012 Summer  2012  Summer       London
# 135017  Chinese Taipei  TPE  1984 Summer  1984  Summer  Los Angeles
# 248276     Netherlands  NED  1924 Summer  1924  Summer        Paris
# 149894         Hungary  HUN  1968 Summer  1968  Summer  Mexico City
#
#                 Sport                                     Event Medal  \
# 237414  Equestrianism  Equestrianism Mixed Dressage, Individual   NaN
# 135017      Athletics           Athletics Women's Javelin Throw   NaN
# ...

# %%
data['Category_BMI'].value_counts()
# Out:
# Category_BMI
# Normal         164473
# Overweight      29877
# Underweight      8099
# Obese            4404
# Name: count, dtype: int64

# %% [markdown]
# **Task** The results may be surprising - there seems to be a lot of "obese" atheletes... Let's investigate it - depict sports in which "obese" athlets won gold medals, and for every sport depict the number of such athlets

# %%
data[(data['Category_BMI'] == 'Obese') & (data['Medal'] == 'Gold')]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 524        297                     Lala Abdul Rashid   M  38.0   169.0
# 620        359        Andrey Khakimovich Abduvaliyev   M  26.0   190.0
# 1366       772                Michael B. "Mike" Adam   M  24.0   175.0
# 1527       846  Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0
# 1528       846  Valerie Kasanita Adams-Vili (-Price)   F  27.0   193.0
# ...        ...                                   ...  ..   ...     ...
# 268660  134407         Leonid Ivanovych Zhabotynskiy   M  30.0   189.0
# 269393  134800                             Zhou Lulu   F  24.0   175.0
# 269541  134872                        Zhuang Xiaoyan   F  23.0   173.0
# 269667  134947                Adrian Edward Zieliski   M  23.0   170.0
# 270034  135095                       Szymon Zikowski   M  24.0   192.0
#
#         Weight          Team  NOC        Games  Year  Season         City  \
# ...

# %%
#your code here
data[(data['Category_BMI'] == 'Obese') & (data['Medal'] == 'Gold')].groupby('Sport')['Name'].nunique().sort_values(ascending=False)
# Out:
# Sport
# Athletics        49
# Weightlifting    45
# Wrestling        25
# Judo             19
# Sailing           7
# Baseball          7
# Bobsleigh         5
# Shooting          5
# Archery           3
# Hockey            3
# Water Polo        3
# Rowing            2
# Curling           2
# Ice Hockey        2
# Softball          2
# Boxing            1
# Luge              1
# Rugby Sevens      1
# Name: Name, dtype: int64
